# %% [markdown]
# # Data Visualization with Python Studio
#
# At this point, you should already have connected with the rest of your group to divide up who is going to do what. Use this notebook to create your visualizations.
#
# Below we set up the dataframe with the Goodreads dataset for you. If you run this cell, you may get an error that some lines were skipped. Do not worry about that! For this studio, we want to focus on creating an effective

# %%
# Here is the setup of the dataframe. Feel free to use .info() or .head() to get a better understanding of what is inside the dataframe!

import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib import style
#import seaborn as sns

df = pd.read_csv(r"C:\Users\nidhi\OneDrive\Desktop\launchcode\data-viz-with-python\books.csv", error_bad_lines=False)

years = []

for y in df['publication_date']:
    date = y.split("/")
    years.append(date[2])

df["year"] = years
# Out:
# C:\Users\nidhi\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# b'Skipping line 3350: expected 12 fields, saw 13\nSkipping line 4704: expected 12 fields, saw 13\nSkipping line 5879: expected 12 fields, saw 13\nSkipping line 8981: expected 12 fields, saw 13\n'

# %%
df.index = df['bookID']

# %%
print("Dataset contains {} rows and {} columns".format(df.shape[0], df.shape[1]))
# Out:
# Dataset contains 11123 rows and 13 columns

# %%
df.head()
# Out:
#         bookID                                              title  \
# bookID
# 1            1  Harry Potter and the Half-Blood Prince (Harry ...
# 2            2  Harry Potter and the Order of the Phoenix (Har...
# 4            4  Harry Potter and the Chamber of Secrets (Harry...
# 5            5  Harry Potter and the Prisoner of Azkaban (Harr...
# 8            8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                            authors  average_rating        isbn         isbn13  \
# bookID
# 1       J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 2       J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 4                     J.K. Rowling            4.42  0439554896  9780439554893
# 5       J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 8       J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
#
#        language_code    num_pages  ratings_count  text_reviews_count  \
# bookID
# 1                eng          652        2095690               27591
# 2                eng          870        2153167               29221
# 4                eng          352           6333                 244
# 5                eng          435        2339585               36325
# 8                eng         2690          41428                 164
#
#        publication_date        publisher  year
# bookID
# 1             9/16/2006  Scholastic Inc.  2006
# 2              9/1/2004  Scholastic Inc.  2004
# 4             11/1/2003       Scholastic  2003
# 5              5/1/2004  Scholastic Inc.  2004
# 8             9/13/2004       Scholastic  2004

# %%
df.replace(to_replace='J.K. Rowling-Mary GrandPré', value = 'J.K. Rowling', inplace=True)

df.head()
# Out:
#         bookID                                              title  \
# bookID
# 1            1  Harry Potter and the Half-Blood Prince (Harry ...
# 2            2  Harry Potter and the Order of the Phoenix (Har...
# 4            4  Harry Potter and the Chamber of Secrets (Harry...
# 5            5  Harry Potter and the Prisoner of Azkaban (Harr...
# 8            8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                            authors  average_rating        isbn         isbn13  \
# bookID
# 1       J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 2       J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 4                     J.K. Rowling            4.42  0439554896  9780439554893
# 5       J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 8       J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
#
#        language_code    num_pages  ratings_count  text_reviews_count  \
# bookID
# 1                eng          652        2095690               27591
# 2                eng          870        2153167               29221
# 4                eng          352           6333                 244
# 5                eng          435        2339585               36325
# 8                eng         2690          41428                 164
#
#        publication_date        publisher  year
# bookID
# 1             9/16/2006  Scholastic Inc.  2006
# 2              9/1/2004  Scholastic Inc.  2004
# 4             11/1/2003       Scholastic  2003
# 5              5/1/2004  Scholastic Inc.  2004
# 8             9/13/2004       Scholastic  2004

# %%
# Use your Python skills to create a visualization here.
#Number of books published by each publisher

top_publisher = df.sort_values(by='ratings_count', ascending=False).head(20)

sb.set(style="darkgrid")
plt.figure(figsize=(10, 10))

color = sb.color_palette("Set2")
ax = sb.barplot(x="ratings_count", y="publisher", data=top_vote, palette=color)

for i in ax.patches:
    ax.text(i.get_width() + .05, i.get_y() + 0.5, str(i.get_width()), fontsize = 10, color = 'k')
plt.show()

# %%
# Use your Python skills to create a visualization here.
#Number of books published per year

ax =df.groupby('publication_date')['title'].count().reset_index().sort_values('title',ascending=False).head(10).set_index('publication_date').plot.bar(figsize=(14,8),rot=0)
plt.title('publication_date',fontsize=20)
plt.xticks(fontsize=15)
for p in ax.patches:
    ax.annotate(str(p.get_height()),(p.get_x()+0.1,p.get_height()+100))

# %%
# Use your Python skills to create a visualization here.
#Text ratings count versus reviews count

rating_review = df.sort_values(by='year', ascending=False).head(20)


sb.set(style="darkgrid")
plt.figure(figsize=(10, 10))

color = sb.color_palette("Set2")
ax = sb.barplot(x="ratings_count", y="text_reviews_count", data=rating_review, palette=color)

for i in ax.patches:
    ax.text(i.get_width() + .05, i.get_y() + 0.5, str(i.get_width()), fontsize = 10, color = 'k')
plt.show()
